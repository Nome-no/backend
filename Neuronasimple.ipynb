# %% [markdown]
# <a href="https://colab.research.google.com/github/Nome-no/backend/blob/master/Neuronasimple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
def step(z):
 return 1 if z >= 0 else 0
def neurona(x1, x2, w1, w2, b):
 z = x1*w1 + x2*w2 + b
 y = step(z)
 return z, y
# Valores base
w1, w2, b = 1, 1, -1.5 # intenta parecerse a una compuerta AND
casos = [(0,0),(0,1),(1,0),(1,1)]
for x1, x2 in casos:
 z, y = neurona(x1, x2, w1, w2, b)
 print(f"Entrada=({x1},{x2}) z={z:.1f} salida={y}")
# Out:
# Entrada=(0,0) z=-2.0 salida=0
# Entrada=(0,1) z=-1.0 salida=0
# Entrada=(1,0) z=-1.0 salida=0
# Entrada=(1,1) z=0.0 salida=1

# %% [markdown]
# **Preguntas: **
# Con que valor de b la neurona se comporta mas parecido a AND?
# El valor óptimo es b = -1.5. Con b = -1.5, solo se activa (salida=1) cuando ambas entradas son 1,
# que es exactamente el comportamiento de la compuerta AND. Si b > -1, la neurona se activaría con (0,1) o (1,0). Si b < -2, nunca se activaría ni siquiera con (1,1).
#
# Que efecto tiene bajar o subir el bias en la salida?
# Subir el bias (hacerlo menos negativo/más positivo) baja el umbral de activación, haciendo que la neurona se active con menos entrada. Bajar el bias sube el umbral, requiriendo más entrada para activarse. El bias controla qué tan "exigente" es la neurona para disparar.
